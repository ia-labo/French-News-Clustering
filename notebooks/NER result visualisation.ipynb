# %% [markdown]
# # Setup

# %%
# %run ../flaubert_token_classification.py
# %run ../tools/utils_ner.py

# %%
import datetime
import math
import os

import matplotlib.pyplot as plt
import itertools
import numpy as np
import tensorflow as tf
from seqeval import metrics
from transformers import (
    TF2_WEIGHTS_NAME,
    FlaubertConfig,
    FlaubertTokenizer,
    GradientAccumulator,
    create_optimizer
)

# %%
model_name="jplu/tf-flaubert-base-cased"
ROOT_FOLDER = os.path.abspath(os.path.join(os.getcwd(), os.pardir)) + "/"
MODEL_PATH = ROOT_FOLDER + "models/ner/"
DATASET_PATH = ROOT_FOLDER + "dataset/custom_dataset/"
LABEL_PATH = DATASET_PATH + "labels.txt"

labels = ['LOC', 'MISC', 'ORG', 'PER', 'O']

num_labels = 5
pad_token_label_id = -1

batch_size=64
max_seq_length = 64

# %%
strategy = tf.distribute.OneDeviceStrategy(device="/gpu:0")

with strategy.scope():
    model = TFFlaubertForTokenClassification.from_pretrained(MODEL_PATH)
    tokenizer = FlaubertTokenizer.from_pretrained(model_name)

# %% [markdown]
# # Evaluation

# %%
def load_and_cache_examples(tokenizer, labels, pad_token_label_id):
    mode = "ner_test"
    # Load data features from cache or dataset file
    cached_features_file = os.path.join(
        DATASET_PATH,
        "cached_{}_{}_{}.tf_record".format(
            mode, list(filter(None, model_name.split("/"))).pop(), str(max_seq_length)
        ),
    )
    if os.path.exists(cached_features_file):
        logging.info("Loading features from cached file %s", cached_features_file)
        dataset, size = load_cache(cached_features_file, max_seq_length)
    else:
        print("Creating features from dataset file at", DATASET_PATH)
        examples = read_examples_from_file(DATASET_PATH, mode)
        features = convert_examples_to_features(
            examples,
            labels,
            max_seq_length,
            tokenizer,
            cls_token_at_end=False,
            # xlnet has a cls token at the end
            cls_token=tokenizer.cls_token,
            cls_token_segment_id=0,
            sep_token=tokenizer.sep_token,
            sep_token_extra=False, # roberta uses an extra separator b/w pairs of sentences, cf. github.com/pytorch/fairseq/commit/1684e166e3da03f5b600dbb7855cb98ddfcd0805
            pad_on_left=False, # pad on the left for xlnet
            pad_token=tokenizer.convert_tokens_to_ids([tokenizer.pad_token])[0],
            pad_token_segment_id=0,
            pad_token_label_id=pad_token_label_id,
        )

        save_cache(features, cached_features_file)
        dataset, size = load_cache(cached_features_file, max_seq_length)

    if mode == "train":
        dataset = dataset.repeat()
        dataset = dataset.shuffle(buffer_size=8192, seed=seed)

    dataset = dataset.batch(batch_size, True)
    dataset = dataset.prefetch(buffer_size=batch_size)

    return dataset, size

# %%
eval_dataset, size = load_and_cache_examples(tokenizer, labels, -1)
eval_dataset = strategy.experimental_distribute_dataset(eval_dataset)
# Out:
# Creating features from dataset file at /home/jupyter/bert_clustering/dataset/custom_dataset/

# %%
def evaluate(strategy, model, tokenizer, labels, pad_token_label_id, mode):
    preds = None

    ner_labels = ["B-LOC", "B-MISC", "B-ORG", "B-PER", "I-LOC", "I-MISC", "I-ORG", "I-PER", "O"]
    
    input_ids = []
    loss_fct = tf.keras.losses.SparseCategoricalCrossentropy(reduction=tf.keras.losses.Reduction.NONE)
    loss = 0.0
    idx = 0
    for idx, (eval_features, eval_labels) in enumerate(eval_dataset):
        if idx > 10:
            break
        inputs = {
            "attention_mask": eval_features["input_mask"],
            "token_type_ids": eval_features["segment_ids"],
            "training": False
        }

        with strategy.scope():
            ner_predictions = model(eval_features["input_ids"], **inputs)
            for i in range(0, batch_size):
                y_pred.append(ner_predictions[0][i])
                y_true.append(eval_labels[i])
                input_ids.append(eval_features["input_ids"])

    return y_true, y_pred, input_ids

# %%
y_true, y_pred, input_ids = evaluate(strategy, model, tokenizer, labels, pad_token_label_id, mode="dev")

# %%
def post_token_classification(predictions, input_mask, tokens, labels, null_tokens):
    entities = []
    str_len = -1
    merge_prev = False

    #tokens = [""] + tokens
    for idx, prediction in enumerate(predictions):
        # Skip tokens added by tokenizer
        if idx >= len(tokens): # or input_mask[idx] != 1:
            continue

        # Merge word splitted
        if merge_prev:
            tokens[idx] = tokens[idx - 1] + tokens[idx]

        if not "</w>" in tokens[idx] and labels[prediction] not in null_tokens:
            merge_prev = True
            continue

        merge_prev = False
        token = tokens[idx].replace("</w>", "")
        start = str_len + 1
        end = len(token) + start
        str_len = end

        if labels[prediction] not in null_tokens:
            entities.append({
                "token": token,
                "label": labels[prediction],
                "start": start,
                "end": end
            })
    return entities

# %%
export = open("export.csv", "w")
export.write("sentence; true; pred\n")

colors = ["\x1b[31m", "\x1b[32m", "\x1b[33m", "\x1b[34m", "\x1b[30m"]

print(" ".join([color + " " + labels[idx] + " \x1b[0m"for idx, color in enumerate(colors)]))

for idx, (true, pred, ids) in enumerate(zip(y_true, y_pred, input_ids)):
    if idx > 100:
        break
    
    sentence = tokenizer.convert_ids_to_tokens(ids[idx % 64])
    sentence = [s for s in sentence[1:] if s != "<pad>" and s != "</s>"]

    new_idx = 0
    new_sentence = [""] * (len([s for s in sentence[1:] if "</w>" in s]) + 1)
    for word in sentence:
        new_sentence[new_idx] += word.replace("</w>", "")
        if "</w>" in word:
            new_idx += 1
    
    true_sentence = ""
    pred_sentence = ""
    sentence_pos = 0
    for sentence_pos, word in enumerate(new_sentence):
        if sentence_pos >= len(pred):
            break

        pred_sentence_idx = pred[sentence_pos] if pred[sentence_pos] < 4 else pred[sentence_pos] - 4
        true_sentence += colors[true[sentence_pos]] + word + " \x1b[0m"
        pred_sentence += colors[pred_sentence_idx] + word + " \x1b[0m"

    print("Actuel :", true_sentence)
    print("Predit :", pred_sentence, "\n")

    # export.write(sentence + "; " + true + "; " + pred + "\n")
export.close()
# Out:
#  LOC   MISC   ORG   PER   O
# Actuel : Fumigènes : Saint - Etienne s en sort avec un match ferme
# Predit : Fumigènes : Saint - Etienne s en sort avec un match ferme
#
# Actuel : La chaîne HBO négocie l adaptation en mini - série du film " Parasite "
# Predit : La chaîne HBO négocie l adaptation en mini - série du film " Parasite "
#
# Actuel : Le gouverneur de Californie veut débloquer 1 , 4 milliard de dollars pour les sans - abris
# Predit : Le gouverneur de Californie veut débloquer 1 , 4 milliard de dollars pour les sans - abris
#
# Actuel : L ex - chef d Elizabeth II se paye Harry le " crétin " et Meghan l " ambitieuse "
# Predit : L ex - chef d Elizabeth II se paye Harry le " crétin " et Meghan l " ambitieuse "
#
# Actuel : L agent de Bale est catégorique
# Predit : L agent de Bale est catégorique
#
# Actuel : [ Mercato ] Un défenseur brésilien dans le viseur ?
# Predit : [ Mercato ] Un défenseur brésilien dans le viseur ?
#
# Actuel : Le kratom , souvent utilisé comme substitut à certains opioïdes , est désormais interdit en France
# Predit : Le kratom , souvent utilisé comme substitut à certains opioïdes , est désormais interdit en France
#
# Actuel : Le Â " showÂ " Ghosn ou la victoire de la communication
# Predit : Le Â " showÂ " Ghosn ou la victoire de la communication
#
# Actuel : Des accidents , " de toute façon il y en aura toujours " : en Haute - Marne , des élus locaux se félicitent du retour à 90 km / h
# Predit : Des accidents , " de toute façon il y en aura toujours " : en Haute - Marne , des élus locaux se félicitent du retour à 90 km / h
#
# Actuel : Le Barça ne pense pas encore à licencier Ernesto Valverde
# Predit : Le Barça ne pense pas encore à licencier Ernesto Valverde
#
# Actuel : Dijon : Laurent Berger en visite
# Predit : Dijon : Laurent Berger en visite
#
# Actuel : Xavier Niel met le paquet dans Molotov . Sera - ce suffisant ?
# Predit : Xavier Niel met le paquet dans Molotov . Sera - ce suffisant ?
#
# Actuel : Des Londoniens partagés après le vote historique de l accord sur le Brexit
# Predit : Des Londoniens partagés après le vote historique de l accord sur le Brexit
#
# Actuel : Retraites : toujours des écoles fermées ou perturbées à Paris
# Predit : Retraites : toujours des écoles fermées ou perturbées à Paris
#
# Actuel : OL - Mercato : 3 départs se précisent à Lyon !
# Predit : OL - Mercato : 3 départs se précisent à Lyon !
#
# Actuel : Les doutes de Ménès sur Icardi
# Predit : Les doutes de Ménès sur Icardi
#
# Actuel : Retraites : des syndicats claquent la porte d une réunion avec le gouvernement
# Predit : Retraites : des syndicats claquent la porte d une réunion avec le gouvernement
#
# Actuel : CES - Le secteur automobile à pleins gaz à la grande messe de la tech
# Predit : CES - Le secteur automobile à pleins gaz à la grande messe de la tech
#
# Actuel : Réforme des retraites : des tensions à Paris en fin de manifestation
# Predit : Réforme des retraites : des tensions à Paris en fin de manifestation
#
# Actuel : Les Monthairons : après l accident qui a fait 2 morts , la conductrice du bus est mise en examen et laissée en liberté
# Predit : Les Monthairons : après l accident qui a fait 2 morts , la conductrice du bus est mise en examen et laissée en liberté
#
# Actuel : LEs MONTHAirons . Accident mortel : la conductrice du car en garde à vue
# Predit : LEs MONTHAirons . Accident mortel : la conductrice du car en garde à vue
#
# Actuel : " Merveilles à Montfermeil " : la défaite des maires
# Predit : " Merveilles à Montfermeil " : la défaite des maires
#
# Actuel : C était chaud entre Messi et Joao Felix ( vidéo )
# Predit : C était chaud entre Messi et Joao Felix ( vidéo )
#
# Actuel : Dopage : l AMA saisit le Tribunal arbitral du sport concernant le dossier russe ( officiel )
# Predit : Dopage : l AMA saisit le Tribunal arbitral du sport concernant le dossier russe ( officiel )
#
# Actuel : Le Samsung Galaxy Fold 2 sera équipé d un Snapdragon 855 et d un module selfie 10 Mp
# Predit : Le Samsung Galaxy Fold 2 sera équipé d un Snapdragon 855 et d un module selfie 10 Mp
#
# Actuel : Fiasco diplomatique de l ' Italie sur la Libye
# Predit : Fiasco diplomatique de l ' Italie sur la Libye
#
# Actuel : Les soldes d hiver démarrent , raccourcis et en pleine grève
# Predit : Les soldes d hiver démarrent , raccourcis et en pleine grève
#
# Actuel : Chambly : Le geste classe pour Correa face à Orléans
# Predit : Chambly : Le geste classe pour Correa face à Orléans
#
# Actuel : Chelsea : Olivier Giroud déjà d accord avec l Inter ?
# Predit : Chelsea : Olivier Giroud déjà d accord avec l Inter ?
#
# Actuel : WB Montreal tease encore leur jeu Batman avec un nouveau logo à assembler
# Predit : WB Montreal tease encore leur jeu Batman avec un nouveau logo à assembler
#
# Actuel : PHOTO Lara Fabian fête ses 50 ans en beauté sur Instagram
# Predit : PHOTO Lara Fabian fête ses 50 ans en beauté sur Instagram
#
# Actuel : AO TENNIS 2 : Enfin un successeur à Top Spin ? | TEST
# Predit : AO TENNIS 2 : Enfin un successeur à Top Spin ? | TEST
#
# Actuel : PSG : Rothen souligne l apport d Icardi
# Predit : PSG : Rothen souligne l apport d Icardi
#
# Actuel : Va - t - il prolonger au PSG ? Mbappé élude la question
# Predit : Va - t - il prolonger au PSG ? Mbappé élude la question
#
# Actuel : VIDEO . Quand Chantal Lauby présentait la météo sur FR3 Auvergne
# Predit : VIDEO . Quand Chantal Lauby présentait la météo sur FR3 Auvergne
#
# Actuel : Mercato : Le Barça n a pas intérêt à faire cette bourde avec Todibo
# Predit : Mercato : Le Barça n a pas intérêt à faire cette bourde avec Todibo
#
# Actuel : PSG - Le quatuor Di Maria - Icardi - Mbappé - Neymar , arme fatale exportable à l international ?
# Predit : PSG - Le quatuor Di Maria - Icardi - Mbappé - Neymar , arme fatale exportable à l international ?
#
# Actuel : Alienware Concept UFO : Dell s attaque à Nintendo
# Predit : Alienware Concept UFO : Dell s attaque à Nintendo
#
# Actuel : Le Sommet de Pau : un sommet anachronique
# Predit : Le Sommet de Pau : un sommet anachronique
#
# Actuel : La prestation de l ancien patron suscite des avis partagés - Nada MERHI
# Predit : La prestation de l ancien patron suscite des avis partagés - Nada MERHI
#
# Actuel : Google dévoile la liste des moteurs alternatifs qu il va proposer sur Android
# Predit : Google dévoile la liste des moteurs alternatifs qu il va proposer sur Android
#
# Actuel : Crash Boeing : la thèse d un missile iranien tiré par erreur avancée à Washington
# Predit : Crash Boeing : la thèse d un missile iranien tiré par erreur avancée à Washington
#
# Actuel : Mercato Barça : Matthaus dithyrambique sur Todibo
# Predit : Mercato Barça : Matthaus dithyrambique sur Todibo
#
# Actuel : PÃ © nuries de cannabis dans l Illinois quelques jours aprÃ <unk>s sa lÃ © galisation
# Predit : PÃ © nuries de cannabis dans l Illinois quelques jours aprÃ <unk>s sa lÃ © galisation
#
# Actuel : Riis , retour imminent
# Predit : Riis , retour imminent
#
# Actuel : Et maintenant , la guerre de Trump au Congrès
# Predit : Et maintenant , la guerre de Trump au Congrès
#
# Actuel : France : Dassault juge excessives les inquiétudes sur Latécoère
# Predit : France : Dassault juge excessives les inquiétudes sur Latécoère
#
# Actuel : La Chambre veut limiter les pouvoirs militaires de Trump
# Predit : La Chambre veut limiter les pouvoirs militaires de Trump
#
# Actuel : Ayoub ( La Villa 5 ) en guerre avec Shanna Kress depuis leur séparation ? Ce détail troublant ( PHOTO )
# Predit : Ayoub ( La Villa 5 ) en guerre avec Shanna Kress depuis leur séparation ? Ce détail troublant ( PHOTO )
#
# Actuel : VIDÉO . La manifestation contre la réforme des retraites à Angers
# Predit : VIDÉO . La manifestation contre la réforme des retraites à Angers
#
# Actuel : Projet d accord en Irlande du Nord pour sortir du blocage politique
# Predit : Projet d accord en Irlande du Nord pour sortir du blocage politique
#
# Actuel : Retraites : deux journalistes arrÃªtÃ © s au dÃ © part de la manifestation
# Predit : Retraites : deux journalistes arrÃªtÃ © s au dÃ © part de la manifestation
#
# Actuel : Volley : La France face Ã l Allemagne pour une place aux JO - 2020
# Predit : Volley : La France face Ã l Allemagne pour une place aux JO - 2020
#
# Actuel : A Wall Street , l accalmie gÃ © opolitique propulse les indices Ã des records
# Predit : A Wall Street , l accalmie gÃ © opolitique propulse les indices Ã des records
#
# Actuel : 8 podcasts pour dÃ © couvrir les coulisses de lâ entrepreneuriat
# Predit : 8 podcasts pour dÃ © couvrir les coulisses de lâ entrepreneuriat
#
# Actuel : Sabrina Gamba : " Dans les citÃ © s , c est compliquÃ © de lancer un projet "
# Predit : Sabrina Gamba : " Dans les citÃ © s , c est compliquÃ © de lancer un projet "
#
# Actuel : â Je suis passÃ © dâ entrepreneur star Ã paria , en un coup de filâ
# Predit : â Je suis passÃ © dâ entrepreneur star Ã paria , en un coup de filâ
#
# Actuel : Travailler dans un gÃ © ant de la Tech Ã Dublin : lâ envers du dÃ © cor
# Predit : Travailler dans un gÃ © ant de la Tech Ã Dublin : lâ envers du dÃ © cor
#
# Actuel : 7 lieux paradisiaques oÃ ¹ on peut conjuguer travail et
# Predit : 7 lieux paradisiaques oÃ ¹ on peut conjuguer travail et
#
# Actuel : Les expositions Ã ne pas manquer Ã Paris en 2020
# Predit : Les expositions Ã ne pas manquer Ã Paris en 2020
#
# Actuel : Les auditeurs ont la parole du 08 janvier 2020
# Predit : Les auditeurs ont la parole du 08 janvier 2020
#
# Actuel : Sud Ouest : 80 . 000 foyers touchÃ © s par des coupures d Ã © lectricitÃ © sauvages
# Predit : Sud Ouest : 80 . 000 foyers touchÃ © s par des coupures d Ã © lectricitÃ © sauvages
#
# Actuel : La Loi du marchÃ © sur France 3 : pourquoi Vincent Lindon doit - il beaucoup Ã ce film ?
# Predit : La Loi du marchÃ © sur France 3 : pourquoi Vincent Lindon doit - il beaucoup Ã ce film ?
#
# Actuel : Dragon BallÂ : tous les vÅ ux exaucÃ © s par les boules de cristal dans la sÃ © rie animÃ © e
# Predit : Dragon BallÂ : tous les vÅ ux exaucÃ © s par les boules de cristal dans la sÃ © rie animÃ © e
#
# Actuel : Tattoo Cover Replay en Streaming - TFX
# Predit : Tattoo Cover Replay en Streaming - TFX
#
# Actuel : InvitÃ © e â Mathilde Imer : 150 citoyens tirÃ © s au sort sâ unissent pour apporter des solutions pour le climat
# Predit : InvitÃ © e â Mathilde Imer : 150 citoyens tirÃ © s au sort sâ unissent pour apporter des solutions pour le climat
#
# Actuel : Coupe d ItalieÂ : le Torino sort le Genoa aux tirs au but - Foot - ITA - Coupe
# Predit : Coupe d ItalieÂ : le Torino sort le Genoa aux tirs au but - Foot - ITA - Coupe
#
# Actuel : Euro : l Allemagne dÃ © marre trÃ <unk>s bien , l Espagne aussi - Hand - Euro ( H )
# Predit : Euro : l Allemagne dÃ © marre trÃ <unk>s bien , l Espagne aussi - Hand - Euro ( H )
#
# Actuel : Comparatif de la valeur des effectifs de Rennes et de l OM - Foot - L1
# Predit : Comparatif de la valeur des effectifs de Rennes et de l OM - Foot - L1
#
# Actuel : Euroligue : le Real Madrid assure face Ã Kaunas - Basket - Euroligue ( H )
# Predit : Euroligue : le Real Madrid assure face Ã Kaunas - Basket - Euroligue ( H )
#
# Actuel : A Paris , Lyon , Genève ... ces beaux jardins d ' hiver
# Predit : A Paris , Lyon , Genève ... ces beaux jardins d ' hiver
#
# Actuel : " Cinq ans après " Charlie " , le danger , pour les créateurs , est moins la censure que l ' autocensure "
# Predit : " Cinq ans après " Charlie " , le danger , pour les créateurs , est moins la censure que l ' autocensure "
#
# Actuel : Soudan : visite historique d ' Abdalla Hamdok dans la région des monts Nuba
# Predit : Soudan : visite historique d ' Abdalla Hamdok dans la région des monts Nuba
#
# Actuel : Le SUA se prépare pour le Superseven
# Predit : Le SUA se prépare pour le Superseven
#
# Actuel : Au sommaire de Minuit Sport : L ' Europe dans le viseur
# Predit : Au sommaire de Minuit Sport : L ' Europe dans le viseur
#
# Actuel : Montpellier : treize personnes intoxiquées à la suite d un incendie volontaire
# Predit : Montpellier : treize personnes intoxiquées à la suite d un incendie volontaire
#
# Actuel : Élections à Taiwan : espoirs et craintes du libraire Hongkongais réfugié à Tapei
# Predit : Élections à Taiwan : espoirs et craintes du libraire Hongkongais réfugié à Tapei
#
# Actuel : Municipales françaises : quels seront les ministres candidats ?
# Predit : Municipales françaises : quels seront les ministres candidats ?
#
# Actuel : Meurtre à La Foa , alerte requin , mobilisation à Tindu : l actu à la 1 du vendredi 10 janvier 2020
# Predit : Meurtre à La Foa , alerte requin , mobilisation à Tindu : l actu à la 1 du vendredi 10 janvier 2020
#
# Actuel : Une base militaire attaquÃ © e au Niger , au moins 25 soldats tuÃ © s
# Predit : Une base militaire attaquÃ © e au Niger , au moins 25 soldats tuÃ © s
#
# Actuel : Prince Harry et Megan Markle : dÃ © part Ã l anglaise ?
# Predit : Prince Harry et Megan Markle : dÃ © part Ã l anglaise ?
#
# Actuel : L Iran a abattu le Boeing de l Ukraine Airlines Ã TÃ © hÃ © ran , affirme Justin Trudeau -
# Predit : L Iran a abattu le Boeing de l Ukraine Airlines Ã TÃ © hÃ © ran , affirme Justin Trudeau -
#
# Actuel : Mali : Lelehoye , un village sous la domination des jihadistes ( 3 / 3 )
# Predit : Mali : Lelehoye , un village sous la domination des jihadistes ( 3 / 3 )
#
# Actuel : Â " FosseÂ " , fascinantes voix de garage
# Predit : Â " FosseÂ " , fascinantes voix de garage
#
# Actuel : La fillette dans le coma victime d un flash - ball , dit son avocat
# Predit : La fillette dans le coma victime d un flash - ball , dit son avocat
#
# Actuel : La mine de la fortune du lundi 11 avril 2016
# Predit : La mine de la fortune du lundi 11 avril 2016
#
# Actuel : Le disco made in France
# Predit : Le disco made in France
#
# Actuel : Les deepfakes , ces vidÃ © os truquÃ © es , menacent les Ã © lections amÃ © ricaines
# Predit : Les deepfakes , ces vidÃ © os truquÃ © es , menacent les Ã © lections amÃ © ricaines
#
# Actuel : Nîmes : Mariola Membrives et David Lagos ouvrent le Festival Flamenco à Paloma
# Predit : Nîmes : Mariola Membrives et David Lagos ouvrent le Festival Flamenco à Paloma
#
# Actuel : Jocelyn Gourvennec : " Objectivement , il y a faute sur les trois pénaltys "
# Predit : Jocelyn Gourvennec : " Objectivement , il y a faute sur les trois pénaltys "
#
# Actuel : Thomas Tuchel : " Nous avons joué avec trop de confiance "
# Predit : Thomas Tuchel : " Nous avons joué avec trop de confiance "
#
# Actuel : Le pétrole se stabilise au lendemain d une séance mouvementée
# Predit : Le pétrole se stabilise au lendemain d une séance mouvementée
#
# Actuel : Inde : visite autorisée de diplomates étrangers au Cachemire
# Predit : Inde : visite autorisée de diplomates étrangers au Cachemire
#
# Actuel : Volley - ball : " Ce n ' est pas encore le moment de la faire la fête " , prévient Toniutti
# Predit : Volley - ball : " Ce n ' est pas encore le moment de la faire la fête " , prévient Toniutti
#
# Actuel : VIDEO . Tout comprendre de la réforme des retraites en une minute
# Predit : VIDEO . Tout comprendre de la réforme des retraites en une minute
#
# Actuel : Marcus Thuram : " Comme en Coupe de France , tout peut arriver ! "
# Predit : Marcus Thuram : " Comme en Coupe de France , tout peut arriver ! "
#
# Actuel : Dakar 2019 : le résumé vidéo de la troisième étape entre San Juan de Marcona et Arequipa
# Predit : Dakar 2019 : le résumé vidéo de la troisième étape entre San Juan de Marcona et Arequipa
#
# Actuel : L Iran riposte , Trump sur le pied de guerre
# Predit : L Iran riposte , Trump sur le pied de guerre
#
# Actuel : Plongée sous les glaces de l ' Antarctique , sur les traces du léopard des mers
# Predit : Plongée sous les glaces de l ' Antarctique , sur les traces du léopard des mers
#
# Actuel : Chantal Delsol : " L ' affaire Matzneff est un désaveu du gauchisme culturel "
# Predit : Chantal Delsol : " L ' affaire Matzneff est un désaveu du gauchisme culturel "
#
# Actuel : Basket - EuroCoupe . Body : " Peut - être qu on s est vu passer avant l heure "
# Predit : Basket - EuroCoupe . Body : " Peut - être qu on s est vu passer avant l heure "
